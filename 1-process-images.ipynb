# %%
# !python -m pip install -U pip
# !python -m pip install pillow-heif
# !pip install rembg
# !pip install PIL

# %%
import os
import glob
from PIL import Image
from pillow_heif import register_heif_opener
from rembg import remove

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# <ul>
#     <li>Resize the images to 512x512</li>
#     <li>Remove background noise</li>
#     <li>Convert from RBGA to RGB</li>
#     <li>Save it with proper format -JPEG- in another file</li>
# </ul>

# %%
register_heif_opener() # Enable support for HEIF images, including HEIC, AVIF, and other formats

# Define target format (e.g., JPEG), size (e.g., 224x224), and quality (0-100)
target_format = "JPEG"
target_size = (512, 512)
quality = 100

# Define path to your image directory
for classname in ['rock', 'paper', 'scissor']:
    src_dir = f"..\\..\\raw_data\\{classname}"
    dst_dir = f"..\\datasets\\procssed_data\\{classname}"

    os.makedirs(dst_dir, exist_ok=True) # Create destination directory if it doesn't exist

    # Find all images using glob
    for filepath in glob.glob(f"{src_dir}\\*"):
        try:
            # Open image with Pillow
            img = Image.open(filepath)
            
            # Resize image
            img = img.resize(target_size)
            
            # Removing the background from the given Image 
            img = remove(img)
            
            # Convering it to the proper format RGB instead of RBGA
            img = img.convert('L') # 'L' for black and white :)

            # Convert to target format and compress
            filename = filepath.split("\\")[-1].split(".")[0]
            img.save(f"{dst_dir}/{filename}.{target_format}", target_format, quality=quality)

            print(f"Converted to JPEG, resized and background removed {filepath}")
        except (OSError, IOError) as e:
            print('somthing went wrong in image proccecing',e)
# Out:
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\1c6c150e-fd4c-4328-b19c-1b245f4637af.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240501_184445.heic
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240501_184727.heic
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240501_213443.heic
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240501_213452.heic
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103813.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103903.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103904.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103905.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103906.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103909.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103910.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103911.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103913.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103914.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103915.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103916.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103917.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103921.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103922.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103923.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103924.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103925.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103926.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103930.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103934.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103935.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103939.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103940.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_103958.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104000.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104001.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104002.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104005.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104006(0).jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104006.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104012.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104014.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104015.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104017.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104018.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104021.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104023.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104025.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104026.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104032.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104033.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104035.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104036.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104047.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104048(0).jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104048.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104049(0).jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104049.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104050.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104051.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104052(0).jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104052.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104054(0).jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104054.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\20240503_104057.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\223b47d5-a7b0-4e36-aa7b-dbdfebf67f8c.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\25b9806b-fef4-40c0-96b1-c5fab3ee1ad0.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\270a6d31-cb08-4d8c-b834-018a86c18450.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\2f1b86c1-bfeb-4923-a885-ca3bc84aba93.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\547a79b7-c7bf-4b38-a4da-e836ea7a1a38.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\5e31b0e6-fe05-46b4-ad50-a0353b468854.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\6d5f5101-5eab-48cc-a6cb-dfdb732ed6aa.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\864f9816-56db-4fa0-83c9-8a7c3fe4e154.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\8e5b8190-4eae-44d4-9eb0-63fb5e9a100b.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\924b9c17-a206-47e3-a241-171228a72700.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\96c3d5ec-b6fa-40d0-b0c1-5604aad90f29.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\bbdb7a10-db48-4a74-acc3-4128d8987efe.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\c99f37af-2af8-4448-a1af-9abc47ddfe16.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\dcad79dd-088b-46c0-a3f9-c6704ecb82ee.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\dcb253b5-5709-42c0-b4b8-9f416ae3094e.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\df7b5e61-8e50-44c9-878a-a6ec1c561196.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock\e06019f1-78a3-4ebe-9b23-513adb7bca8c.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\rock
HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2618.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2619.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2620.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2669.JPG
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2670.JPG
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2671.JPG
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2677.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2680.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2681.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2684.JPG
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2687.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_2688.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4357.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4360.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4371.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4375.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4378.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4386.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4387.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4393.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4397.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4402.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4406.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4425.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4426.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4427.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4428.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4429.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4430.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4431.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4432.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\paper\IMG_4433.HEIC
# ...
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\image9.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0022.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0023.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0024.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0025.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0026.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0027.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0028.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0029.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0030.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240501-WA0031.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0001.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0002.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0003.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0004.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0005.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0006.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0007.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0008.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0009.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0010.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0011.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0012.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0013.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0014.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0015.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0016.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0017.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0018.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0019.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0020.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0021.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0022.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0023.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0024.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0025.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0026.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0027.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0028.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0029.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0030.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0031.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0032.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0033.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0034.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0035.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0036.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0037.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0038.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0039.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0040.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0041.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0042.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0043.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0044.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0045.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0046.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0047.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0048.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0049.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0050.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0051.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0052.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0053.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0054.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0055.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0056.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0057.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0058.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0059.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0060.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0061.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0062.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0063.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0064.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0065.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0066.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0068.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0069.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0070.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0071.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0072.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0073.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0074.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG-20240502-WA0075.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0377.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0378.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0385.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0387.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0389.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0390.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0391.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0392.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0394.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_0395.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2318.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2320.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2372.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2378.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2379.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2381.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2382.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2390.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2405.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2406.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2409.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2419.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2614.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2615.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2616.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2621.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2626.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2676.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2679.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2682.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_2686.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4358.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4362.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4373.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4374.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4380.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4384.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4391.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4394.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4399.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4401.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4408.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4447.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4448.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4449.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4450.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4451.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4452.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4453.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4454.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4455.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_4456.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6640.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6642.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6647.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6648.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6653.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6655.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6656.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6659.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6660.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6669.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_6670.HEIC
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9307.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9315.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9318.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9326.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9343.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9350.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9351.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9352.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9357.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\IMG_9360.jpeg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-10-27.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-10-34.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-10-40.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-10-45.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-10-51.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-11-40.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-11-48.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-11-53.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-12-02.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-12-11.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_15-12-15.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\photo_2024-05-01_20-15-54.jpg
# Converted to JPEG, resized and background removed ..\..\raw_data\scissor\WhatsApp Image 2024-05-01 at 3.39.11 PM.jpeg

# %% [markdown]
# ### Making sure JPEG is the only format in the output

# %%
formats = set()
filepaths = glob.glob('..\\datasets\\procssed_data\\*\\*')

for f in filepaths:
    formats.add(f.split('.')[-1].lower())

print(f'{formats} Must be only JPEG/JPG')
# Out:
# {'jpeg'} Must be only JPEG/JPG

# %% [markdown]
# ### Count number of `input` vs `output`

# %%
filepaths_not_processed = glob.glob('..\\..\\raw_data\\*\\*')
filepaths_processed = glob.glob('..\\datasets\\procssed_data\\*\\*')
print(f'{len(filepaths_not_processed)} is number of images in raw_data')
print(f'{len(filepaths_processed)} is number of images in processed_data')
# Out:
# 843 is number of images in raw_data
# 841 is number of images in processed_data
